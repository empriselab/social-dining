# %% [markdown]
# # Verify annotation values

# %%
import glob
import pympi


empty_annotation_value = ['']
food_annotation_values = ['fork', 'knife', 'spoon', 'chopsticks', 'hand']
drink_annotation_values = ['cup', 'bottle']
disruption_annotation_values = ['light_off', 'participant_left']

valid_annotation_values = {
    'mouth_open': empty_annotation_value,

    'food_to_mouth': food_annotation_values, # can also have an empty annotation value - there is only one special case (see below and/or annotation instructions)
    'food_entered': food_annotation_values,
    'food_lifted': food_annotation_values, # can also have an empty annotation value - there is only one special case (see below and/or annotation instructions)

    'drink_to_mouth': drink_annotation_values,
    'drink_entered': drink_annotation_values,
    'drink_lifted': drink_annotation_values,

    'napkin_to_mouth': empty_annotation_value,
    'napkin_entered': empty_annotation_value,
    'napkin_lifted': empty_annotation_value,

    'disruption': disruption_annotation_values
}

annotations_folder = f'/home/janko/Desktop/social-dining/data/annotation/annotation-files'

for annotation_file in sorted(glob.glob(f'{annotations_folder}/*.eaf')):
    eaf_obj1 = pympi.Elan.Eaf(annotation_file)
    available_tier_names = eaf_obj1.get_tier_names()

    for tier_name, valid_values in valid_annotation_values.items():
        if tier_name not in available_tier_names:
            print(f"WARNING: no '{tier_name}' tier name found in file: {annotation_file}")
        else:
            for annotation in eaf_obj1.get_annotation_data_for_tier(tier_name):
                # assert annotation[2] in valid_values, f"ERROR: the annotation {annotation} with tier name '{tier_name}' must have a value from {valid_values}. Found in file: {annotation_file}"
                if annotation[2] not in valid_values:
                    print(f"ERROR: the annotation {annotation} with tier name '{tier_name}' must have a value from {valid_values}. Found in file: {annotation_file}")

# Fixed errors (6):
    # AssertionError: ERROR: the annotation (1642498, 1646371, '') with tier name 'drink_to_mouth' must have a value from ['cup', 'bottle']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/05_3.eaf
    # AssertionError: ERROR: the annotation (1141239, 1141639, 'hand') with tier name 'drink_entered' must have a value from ['cup', 'bottle']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/07_2.eaf
    # Immediately next to AssertionError: ERROR: the annotation (1141239, 1141639, 'hand') with tier name 'drink_entered' must have a value from ['cup', 'bottle']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/07_2.eaf
    # AssertionError: ERROR: the annotation (2828970, 2829370, 'fork') with tier name 'drink_lifted' must have a value from ['cup', 'bottle']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/08_1.eaf
    # AssertionError: ERROR: the annotation (1105737, 1106447, '') with tier name 'food_to_mouth' must have a value from ['fork', 'knife', 'spoon', 'chopsticks', 'hand']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_3.eaf
    # AssertionError: ERROR: the annotation (510900, 511300, 'hand') with tier name 'drink_lifted' must have a value from ['cup', 'bottle']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/22_2.eaf

# Only one special case that is accepted (the person ate without the use of any utensil/hand and the person just moved head towards the table to eat a bite)
    # ERROR: the annotation (2795170, 2795650, '') with tier name 'food_to_mouth' must have a value from ['fork', 'knife', 'spoon', 'chopsticks', 'hand']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_1.eaf
    # ERROR: the annotation (2793518, 2793918, '') with tier name 'food_lifted' must have a value from ['fork', 'knife', 'spoon', 'chopsticks', 'hand']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_1.eaf
# Out:
# ERROR: the annotation (2795170, 2795650, '') with tier name 'food_to_mouth' must have a value from ['fork', 'knife', 'spoon', 'chopsticks', 'hand']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_1.eaf
# ERROR: the annotation (2793518, 2793918, '') with tier name 'food_lifted' must have a value from ['fork', 'knife', 'spoon', 'chopsticks', 'hand']. Found in file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_1.eaf

# %% [markdown]
# # Verify annotation order and count

# %%
import glob
import pympi

tier_names = [
    'mouth_open',
    'food_lifted',
    'food_to_mouth',

    'drink_lifted',
    'drink_to_mouth',

    'napkin_lifted',
    'napkin_to_mouth'
]
annotations_folder = f'/home/janko/Desktop/social-dining/data/annotation/annotation-files'
# Milliseconds to minutes
MTM = 60000

for annotation_file in sorted(glob.glob(f'{annotations_folder}/*.eaf')):
    print(f"In file: {annotation_file}")
    eaf_obj1 = pympi.Elan.Eaf(annotation_file)
    available_tier_names = eaf_obj1.get_tier_names()

    annotations = {}
    for tier_name in tier_names:
        if tier_name not in available_tier_names:
            print(f"\t WARNING: no '{tier_name}' tier name found")
        else:
            annotations[tier_name] = sorted(eaf_obj1.get_annotation_data_for_tier(tier_name), key=lambda x: x[0])

    # The food_lifted annotation must precede the food_to_mouth annotation unless the food is already lifted at the beginning of the video
    # The mouth_open annotation must precede the food_to_mouth annotation
    print(f"\t #food_lifted annotations: {len(annotations['food_lifted'])}\t #mouth_open annotations: {len(annotations['mouth_open'])}\t #food_to_mouth annotations: {len(annotations['food_to_mouth'])}")
    assert len(annotations['mouth_open']) == len(annotations['food_to_mouth']), f"\t ERROR: the number of 'mouth_open' annotations {len(annotations['mouth_open'])} must be equal to the number of 'food_to_mouth' annotations {len(annotations['food_to_mouth'])}"
    i1, i2 = 0, 0
    while i2 < len(annotations['food_to_mouth']):
        if i1 == 0 and annotations['food_lifted'][i1][0] > annotations['food_to_mouth'][i2][0]:
            print(f"\t WARNING: food already lifted at the beginning of the video")
        else:
            assert annotations['food_lifted'][i1][0] <= annotations['food_to_mouth'][i2][0], f"\t ERROR: the 'food_lifted' annotation at {annotations['food_lifted'][i1][0]/MTM} does not precede the 'food_to_mouth' annotation at {annotations['food_to_mouth'][i2][0]/MTM}"
            i1 += 1
        assert annotations['mouth_open'][i2][0] <= annotations['food_to_mouth'][i2][0], f"\t ERROR: the 'mouth_open' annotation at {annotations['mouth_open'][i2][0]/MTM} does not precede the 'food_to_mouth' annotation at {annotations['food_to_mouth'][i3][0]/MTM}"
        i2 += 1

    # The drink_lifted annotation must precede the drink_to_mouth annotation unless the drink is already lifted at the beginning of the video
    print(f"\t #drink_lifted annotations: {len(annotations['drink_lifted'])}\t #drink_to_mouth annotations: {len(annotations['drink_to_mouth'])}")
    i1, i2 = 0, 0
    while i2 < len(annotations['drink_to_mouth']):
        if i1 == 0 and annotations['drink_lifted'][i1][0] > annotations['drink_to_mouth'][i2][0]:
            print(f"\t WARNING: drink already lifted at the beginning of the video")
        else:
            assert annotations['drink_lifted'][i1][0] <= annotations['drink_to_mouth'][i2][0], f"ERROR: the 'drink_lifted' annotation at {annotations['drink_lifted'][i1][0]/MTM} does not precede the 'drink_to_mouth' annotation at {annotations['drink_to_mouth'][i2][0]/MTM}"
            i1 += 1
        i2 += 1

    # The napkin_lifted annotation must precede the napkin_to_mouth annotation unless the napkin is already lifted at the beginning of the video.    
    print(f"\t #napkin_lifted annotations: {len(annotations['napkin_lifted'])}\t #napkin_to_mouth annotations: {len(annotations['napkin_to_mouth'])}")
    i1, i2 = 0, 0
    while i2 < len(annotations['napkin_to_mouth']):
        if i1 == 0 and annotations['napkin_lifted'][i1][0] > annotations['napkin_to_mouth'][i2][0]:
            print(f"\t WARNING: napkin already lifted at the beginning of the video")
        else:
            assert annotations['napkin_lifted'][i1][0] <= annotations['napkin_to_mouth'][i2][0], f"ERROR: the 'napkin_lifted' annotation at {annotations['napkin_lifted'][i1][0]/MTM} does not precede the 'napkin_to_mouth' annotation at {annotations['napkin_to_mouth'][i2][0]/MTM}"
            i1 += 1
        i2 += 1

    print('=' * 100)
# Out:
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/01_1.eaf
# 	 #food_lifted annotations: 38	 #mouth_open annotations: 38	 #food_to_mouth annotations: 38
# 	 #drink_lifted annotations: 12	 #drink_to_mouth annotations: 12
# 	 #napkin_lifted annotations: 14	 #napkin_to_mouth annotations: 14
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/01_2.eaf
# 	 #food_lifted annotations: 79	 #mouth_open annotations: 79	 #food_to_mouth annotations: 79
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/01_3.eaf
# 	 #food_lifted annotations: 66	 #mouth_open annotations: 66	 #food_to_mouth annotations: 66
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 9
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/02_1.eaf
# 	 #food_lifted annotations: 18	 #mouth_open annotations: 18	 #food_to_mouth annotations: 18
# 	 #drink_lifted annotations: 11	 #drink_to_mouth annotations: 11
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/02_2.eaf
# 	 #food_lifted annotations: 62	 #mouth_open annotations: 62	 #food_to_mouth annotations: 62
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/02_3.eaf
# 	 #food_lifted annotations: 72	 #mouth_open annotations: 72	 #food_to_mouth annotations: 72
# 	 #drink_lifted annotations: 3	 #drink_to_mouth annotations: 3
# 	 #napkin_lifted annotations: 23	 #napkin_to_mouth annotations: 23
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/03_1.eaf
# 	 #food_lifted annotations: 42	 #mouth_open annotations: 42	 #food_to_mouth annotations: 42
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 17	 #napkin_to_mouth annotations: 17
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/03_2.eaf
# 	 #food_lifted annotations: 79	 #mouth_open annotations: 79	 #food_to_mouth annotations: 79
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 6	 #napkin_to_mouth annotations: 6
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/03_3.eaf
# 	 #food_lifted annotations: 38	 #mouth_open annotations: 38	 #food_to_mouth annotations: 38
# 	 #drink_lifted annotations: 13	 #drink_to_mouth annotations: 13
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/04_1.eaf
# 	 #food_lifted annotations: 82	 #mouth_open annotations: 83	 #food_to_mouth annotations: 83
# 	 WARNING: food already lifted at the beginning of the video
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 8
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/04_2.eaf
# 	 #food_lifted annotations: 57	 #mouth_open annotations: 57	 #food_to_mouth annotations: 57
# 	 #drink_lifted annotations: 15	 #drink_to_mouth annotations: 15
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/04_3.eaf
# 	 #food_lifted annotations: 135	 #mouth_open annotations: 135	 #food_to_mouth annotations: 135
# 	 #drink_lifted annotations: 12	 #drink_to_mouth annotations: 12
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/05_1.eaf
# 	 #food_lifted annotations: 16	 #mouth_open annotations: 16	 #food_to_mouth annotations: 16
# 	 #drink_lifted annotations: 13	 #drink_to_mouth annotations: 13
# 	 #napkin_lifted annotations: 16	 #napkin_to_mouth annotations: 16
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/05_2.eaf
# 	 #food_lifted annotations: 12	 #mouth_open annotations: 12	 #food_to_mouth annotations: 12
# 	 #drink_lifted annotations: 55	 #drink_to_mouth annotations: 55
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/05_3.eaf
# 	 #food_lifted annotations: 10	 #mouth_open annotations: 10	 #food_to_mouth annotations: 10
# 	 #drink_lifted annotations: 42	 #drink_to_mouth annotations: 41
# 	 #napkin_lifted annotations: 3	 #napkin_to_mouth annotations: 3
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/06_1.eaf
# 	 #food_lifted annotations: 38	 #mouth_open annotations: 38	 #food_to_mouth annotations: 38
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/06_2.eaf
# 	 #food_lifted annotations: 69	 #mouth_open annotations: 69	 #food_to_mouth annotations: 69
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 6	 #napkin_to_mouth annotations: 6
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/06_3.eaf
# 	 #food_lifted annotations: 74	 #mouth_open annotations: 74	 #food_to_mouth annotations: 74
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 12	 #napkin_to_mouth annotations: 12
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/07_1.eaf
# 	 #food_lifted annotations: 35	 #mouth_open annotations: 35	 #food_to_mouth annotations: 35
# 	 #drink_lifted annotations: 0	 #drink_to_mouth annotations: 0
# 	 #napkin_lifted annotations: 27	 #napkin_to_mouth annotations: 27
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/07_2.eaf
# 	 #food_lifted annotations: 32	 #mouth_open annotations: 32	 #food_to_mouth annotations: 32
# 	 #drink_lifted annotations: 16	 #drink_to_mouth annotations: 16
# 	 #napkin_lifted annotations: 6	 #napkin_to_mouth annotations: 6
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/07_3.eaf
# 	 #food_lifted annotations: 29	 #mouth_open annotations: 29	 #food_to_mouth annotations: 29
# 	 #drink_lifted annotations: 2	 #drink_to_mouth annotations: 2
# 	 #napkin_lifted annotations: 19	 #napkin_to_mouth annotations: 19
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/08_1.eaf
# 	 #food_lifted annotations: 91	 #mouth_open annotations: 91	 #food_to_mouth annotations: 91
# 	 #drink_lifted annotations: 12	 #drink_to_mouth annotations: 12
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/08_2.eaf
# 	 #food_lifted annotations: 28	 #mouth_open annotations: 28	 #food_to_mouth annotations: 28
# 	 #drink_lifted annotations: 3	 #drink_to_mouth annotations: 3
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/08_3.eaf
# 	 #food_lifted annotations: 50	 #mouth_open annotations: 50	 #food_to_mouth annotations: 50
# 	 #drink_lifted annotations: 10	 #drink_to_mouth annotations: 10
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_1.eaf
# 	 #food_lifted annotations: 63	 #mouth_open annotations: 63	 #food_to_mouth annotations: 63
# 	 #drink_lifted annotations: 11	 #drink_to_mouth annotations: 11
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_2.eaf
# 	 #food_lifted annotations: 114	 #mouth_open annotations: 114	 #food_to_mouth annotations: 114
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 8	 #napkin_to_mouth annotations: 8
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_3.eaf
# 	 #food_lifted annotations: 106	 #mouth_open annotations: 106	 #food_to_mouth annotations: 106
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/10_1.eaf
# 	 #food_lifted annotations: 220	 #mouth_open annotations: 220	 #food_to_mouth annotations: 220
# 	 #drink_lifted annotations: 0	 #drink_to_mouth annotations: 0
# 	 #napkin_lifted annotations: 4	 #napkin_to_mouth annotations: 4
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/10_2.eaf
# 	 #food_lifted annotations: 139	 #mouth_open annotations: 139	 #food_to_mouth annotations: 139
# 	 #drink_lifted annotations: 20	 #drink_to_mouth annotations: 20
# 	 #napkin_lifted annotations: 9	 #napkin_to_mouth annotations: 9
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/10_3.eaf
# 	 #food_lifted annotations: 172	 #mouth_open annotations: 172	 #food_to_mouth annotations: 172
# 	 #drink_lifted annotations: 11	 #drink_to_mouth annotations: 11
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/11_1.eaf
# 	 #food_lifted annotations: 84	 #mouth_open annotations: 84	 #food_to_mouth annotations: 84
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/11_2.eaf
# 	 #food_lifted annotations: 72	 #mouth_open annotations: 72	 #food_to_mouth annotations: 72
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/11_3.eaf
# 	 #food_lifted annotations: 77	 #mouth_open annotations: 77	 #food_to_mouth annotations: 77
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 4	 #napkin_to_mouth annotations: 4
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/12_1.eaf
# 	 #food_lifted annotations: 21	 #mouth_open annotations: 21	 #food_to_mouth annotations: 21
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 9
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/12_2.eaf
# 	 #food_lifted annotations: 108	 #mouth_open annotations: 108	 #food_to_mouth annotations: 108
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/12_3.eaf
# 	 #food_lifted annotations: 23	 #mouth_open annotations: 23	 #food_to_mouth annotations: 23
# 	 #drink_lifted annotations: 48	 #drink_to_mouth annotations: 48
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/13_1.eaf
# 	 #food_lifted annotations: 47	 #mouth_open annotations: 47	 #food_to_mouth annotations: 47
# 	 #drink_lifted annotations: 18	 #drink_to_mouth annotations: 18
# 	 #napkin_lifted annotations: 38	 #napkin_to_mouth annotations: 38
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/13_2.eaf
# 	 #food_lifted annotations: 396	 #mouth_open annotations: 396	 #food_to_mouth annotations: 396
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/13_3.eaf
# 	 #food_lifted annotations: 298	 #mouth_open annotations: 298	 #food_to_mouth annotations: 298
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 9
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/14_1.eaf
# 	 #food_lifted annotations: 60	 #mouth_open annotations: 60	 #food_to_mouth annotations: 60
# 	 #drink_lifted annotations: 0	 #drink_to_mouth annotations: 0
# 	 #napkin_lifted annotations: 6	 #napkin_to_mouth annotations: 6
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/14_2.eaf
# 	 #food_lifted annotations: 160	 #mouth_open annotations: 160	 #food_to_mouth annotations: 160
# 	 #drink_lifted annotations: 0	 #drink_to_mouth annotations: 0
# 	 #napkin_lifted annotations: 19	 #napkin_to_mouth annotations: 19
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/14_3.eaf
# 	 #food_lifted annotations: 71	 #mouth_open annotations: 71	 #food_to_mouth annotations: 71
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 26	 #napkin_to_mouth annotations: 26
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_1.eaf
# 	 #food_lifted annotations: 40	 #mouth_open annotations: 40	 #food_to_mouth annotations: 40
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 9	 #napkin_to_mouth annotations: 9
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_2.eaf
# 	 #food_lifted annotations: 76	 #mouth_open annotations: 76	 #food_to_mouth annotations: 76
# 	 #drink_lifted annotations: 12	 #drink_to_mouth annotations: 12
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_3.eaf
# 	 #food_lifted annotations: 80	 #mouth_open annotations: 80	 #food_to_mouth annotations: 80
# 	 #drink_lifted annotations: 20	 #drink_to_mouth annotations: 20
# 	 #napkin_lifted annotations: 8	 #napkin_to_mouth annotations: 8
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/16_1.eaf
# 	 #food_lifted annotations: 60	 #mouth_open annotations: 60	 #food_to_mouth annotations: 60
# 	 #drink_lifted annotations: 2	 #drink_to_mouth annotations: 2
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/16_2.eaf
# 	 #food_lifted annotations: 21	 #mouth_open annotations: 21	 #food_to_mouth annotations: 21
# 	 #drink_lifted annotations: 8	 #drink_to_mouth annotations: 8
# 	 #napkin_lifted annotations: 13	 #napkin_to_mouth annotations: 13
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/16_3.eaf
# 	 #food_lifted annotations: 120	 #mouth_open annotations: 120	 #food_to_mouth annotations: 120
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/17_1.eaf
# 	 #food_lifted annotations: 33	 #mouth_open annotations: 33	 #food_to_mouth annotations: 33
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/17_2.eaf
# 	 #food_lifted annotations: 56	 #mouth_open annotations: 56	 #food_to_mouth annotations: 56
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 4	 #napkin_to_mouth annotations: 4
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/17_3.eaf
# 	 #food_lifted annotations: 72	 #mouth_open annotations: 72	 #food_to_mouth annotations: 72
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_1.eaf
# 	 #food_lifted annotations: 138	 #mouth_open annotations: 138	 #food_to_mouth annotations: 138
# 	 #drink_lifted annotations: 11	 #drink_to_mouth annotations: 11
# 	 #napkin_lifted annotations: 33	 #napkin_to_mouth annotations: 33
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_2.eaf
# 	 #food_lifted annotations: 56	 #mouth_open annotations: 56	 #food_to_mouth annotations: 56
# 	 #drink_lifted annotations: 23	 #drink_to_mouth annotations: 23
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_3.eaf
# 	 #food_lifted annotations: 94	 #mouth_open annotations: 94	 #food_to_mouth annotations: 94
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/19_1.eaf
# 	 #food_lifted annotations: 62	 #mouth_open annotations: 62	 #food_to_mouth annotations: 62
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 24	 #napkin_to_mouth annotations: 24
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/19_2.eaf
# 	 #food_lifted annotations: 55	 #mouth_open annotations: 56	 #food_to_mouth annotations: 56
# 	 WARNING: food already lifted at the beginning of the video
# 	 #drink_lifted annotations: 8	 #drink_to_mouth annotations: 8
# 	 #napkin_lifted annotations: 3	 #napkin_to_mouth annotations: 3
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/19_3.eaf
# 	 #food_lifted annotations: 69	 #mouth_open annotations: 69	 #food_to_mouth annotations: 69
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 12	 #napkin_to_mouth annotations: 12
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/20_1.eaf
# 	 #food_lifted annotations: 45	 #mouth_open annotations: 45	 #food_to_mouth annotations: 45
# 	 #drink_lifted annotations: 3	 #drink_to_mouth annotations: 3
# 	 #napkin_lifted annotations: 6	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/20_2.eaf
# 	 #food_lifted annotations: 55	 #mouth_open annotations: 55	 #food_to_mouth annotations: 55
# 	 #drink_lifted annotations: 2	 #drink_to_mouth annotations: 2
# 	 #napkin_lifted annotations: 3	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/20_3.eaf
# 	 #food_lifted annotations: 64	 #mouth_open annotations: 64	 #food_to_mouth annotations: 64
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/21_1.eaf
# 	 #food_lifted annotations: 97	 #mouth_open annotations: 97	 #food_to_mouth annotations: 97
# 	 #drink_lifted annotations: 6	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 16	 #napkin_to_mouth annotations: 16
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/21_2.eaf
# 	 #food_lifted annotations: 96	 #mouth_open annotations: 97	 #food_to_mouth annotations: 97
# 	 WARNING: food already lifted at the beginning of the video
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 9
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/21_3.eaf
# 	 #food_lifted annotations: 67	 #mouth_open annotations: 67	 #food_to_mouth annotations: 67
# 	 #drink_lifted annotations: 28	 #drink_to_mouth annotations: 28
# 	 #napkin_lifted annotations: 10	 #napkin_to_mouth annotations: 10
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/22_1.eaf
# 	 #food_lifted annotations: 83	 #mouth_open annotations: 83	 #food_to_mouth annotations: 83
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 12	 #napkin_to_mouth annotations: 12
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/22_2.eaf
# 	 #food_lifted annotations: 39	 #mouth_open annotations: 40	 #food_to_mouth annotations: 40
# 	 WARNING: food already lifted at the beginning of the video
# 	 #drink_lifted annotations: 18	 #drink_to_mouth annotations: 18
# 	 #napkin_lifted annotations: 18	 #napkin_to_mouth annotations: 18
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/22_3.eaf
# 	 #food_lifted annotations: 84	 #mouth_open annotations: 84	 #food_to_mouth annotations: 84
# 	 #drink_lifted annotations: 10	 #drink_to_mouth annotations: 10
# 	 #napkin_lifted annotations: 23	 #napkin_to_mouth annotations: 23
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/23_1.eaf
# 	 #food_lifted annotations: 61	 #mouth_open annotations: 61	 #food_to_mouth annotations: 61
# 	 #drink_lifted annotations: 9	 #drink_to_mouth annotations: 9
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/23_2.eaf
# 	 #food_lifted annotations: 28	 #mouth_open annotations: 28	 #food_to_mouth annotations: 28
# 	 #drink_lifted annotations: 3	 #drink_to_mouth annotations: 3
# 	 #napkin_lifted annotations: 4	 #napkin_to_mouth annotations: 4
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/23_3.eaf
# 	 #food_lifted annotations: 27	 #mouth_open annotations: 27	 #food_to_mouth annotations: 27
# 	 #drink_lifted annotations: 11	 #drink_to_mouth annotations: 11
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/24_1.eaf
# 	 #food_lifted annotations: 106	 #mouth_open annotations: 106	 #food_to_mouth annotations: 106
# 	 #drink_lifted annotations: 10	 #drink_to_mouth annotations: 10
# 	 #napkin_lifted annotations: 14	 #napkin_to_mouth annotations: 14
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/24_2.eaf
# 	 #food_lifted annotations: 130	 #mouth_open annotations: 130	 #food_to_mouth annotations: 130
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/24_3.eaf
# 	 #food_lifted annotations: 39	 #mouth_open annotations: 39	 #food_to_mouth annotations: 39
# 	 #drink_lifted annotations: 18	 #drink_to_mouth annotations: 18
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/25_1.eaf
# 	 #food_lifted annotations: 70	 #mouth_open annotations: 70	 #food_to_mouth annotations: 70
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 8	 #napkin_to_mouth annotations: 8
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/25_2.eaf
# 	 #food_lifted annotations: 69	 #mouth_open annotations: 69	 #food_to_mouth annotations: 69
# 	 #drink_lifted annotations: 4	 #drink_to_mouth annotations: 4
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/25_3.eaf
# 	 #food_lifted annotations: 49	 #mouth_open annotations: 49	 #food_to_mouth annotations: 49
# 	 #drink_lifted annotations: 10	 #drink_to_mouth annotations: 10
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_1.eaf
# 	 #food_lifted annotations: 62	 #mouth_open annotations: 62	 #food_to_mouth annotations: 62
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_2.eaf
# 	 #food_lifted annotations: 43	 #mouth_open annotations: 43	 #food_to_mouth annotations: 43
# 	 #drink_lifted annotations: 31	 #drink_to_mouth annotations: 31
# 	 #napkin_lifted annotations: 8	 #napkin_to_mouth annotations: 8
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_3.eaf
# 	 #food_lifted annotations: 55	 #mouth_open annotations: 55	 #food_to_mouth annotations: 55
# 	 #drink_lifted annotations: 5	 #drink_to_mouth annotations: 5
# 	 #napkin_lifted annotations: 5	 #napkin_to_mouth annotations: 5
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/27_1.eaf
# 	 #food_lifted annotations: 47	 #mouth_open annotations: 47	 #food_to_mouth annotations: 47
# 	 #drink_lifted annotations: 24	 #drink_to_mouth annotations: 24
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/27_2.eaf
# 	 #food_lifted annotations: 63	 #mouth_open annotations: 63	 #food_to_mouth annotations: 63
# 	 #drink_lifted annotations: 31	 #drink_to_mouth annotations: 31
# 	 #napkin_lifted annotations: 7	 #napkin_to_mouth annotations: 7
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/27_3.eaf
# 	 #food_lifted annotations: 79	 #mouth_open annotations: 79	 #food_to_mouth annotations: 79
# 	 #drink_lifted annotations: 39	 #drink_to_mouth annotations: 39
# 	 #napkin_lifted annotations: 8	 #napkin_to_mouth annotations: 8
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_1.eaf
# 	 #food_lifted annotations: 149	 #mouth_open annotations: 149	 #food_to_mouth annotations: 149
# 	 #drink_lifted annotations: 12	 #drink_to_mouth annotations: 12
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_2.eaf
# 	 #food_lifted annotations: 161	 #mouth_open annotations: 161	 #food_to_mouth annotations: 161
# 	 #drink_lifted annotations: 8	 #drink_to_mouth annotations: 8
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_3.eaf
# 	 #food_lifted annotations: 57	 #mouth_open annotations: 57	 #food_to_mouth annotations: 57
# 	 #drink_lifted annotations: 21	 #drink_to_mouth annotations: 21
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_1.eaf
# 	 #food_lifted annotations: 96	 #mouth_open annotations: 96	 #food_to_mouth annotations: 96
# 	 #drink_lifted annotations: 13	 #drink_to_mouth annotations: 13
# 	 #napkin_lifted annotations: 3	 #napkin_to_mouth annotations: 3
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_2.eaf
# 	 #food_lifted annotations: 99	 #mouth_open annotations: 99	 #food_to_mouth annotations: 99
# 	 #drink_lifted annotations: 8	 #drink_to_mouth annotations: 8
# 	 #napkin_lifted annotations: 4	 #napkin_to_mouth annotations: 4
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/29_3.eaf
# 	 #food_lifted annotations: 70	 #mouth_open annotations: 70	 #food_to_mouth annotations: 70
# 	 #drink_lifted annotations: 34	 #drink_to_mouth annotations: 34
# 	 #napkin_lifted annotations: 0	 #napkin_to_mouth annotations: 0
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/30_1.eaf
# 	 #food_lifted annotations: 37	 #mouth_open annotations: 37	 #food_to_mouth annotations: 37
# 	 #drink_lifted annotations: 2	 #drink_to_mouth annotations: 2
# 	 #napkin_lifted annotations: 1	 #napkin_to_mouth annotations: 1
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/30_2.eaf
# 	 #food_lifted annotations: 34	 #mouth_open annotations: 34	 #food_to_mouth annotations: 34
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 7
# 	 #napkin_lifted annotations: 16	 #napkin_to_mouth annotations: 16
# ====================================================================================================
# In file: /home/janko/Desktop/social-dining/data/annotation/annotation-files/30_3.eaf
# 	 #food_lifted annotations: 54	 #mouth_open annotations: 54	 #food_to_mouth annotations: 54
# 	 #drink_lifted annotations: 7	 #drink_to_mouth annotations: 6
# 	 #napkin_lifted annotations: 2	 #napkin_to_mouth annotations: 2
# ====================================================================================================

# %% [markdown]
# # Get values to unify disruption period start and end times across videos from one session
#
# After running this script, manually change the few ELAN files with the min and max values.

# %%
import glob
import pympi

annotations_folder = f'/home/janko/Desktop/social-dining/data/annotation/annotation-files'

i = 0
for annotation_file in sorted(glob.glob(f'{annotations_folder}/*.eaf')):
    eaf_obj1 = pympi.Elan.Eaf(annotation_file)

    x = eaf_obj1.get_annotation_data_for_tier('disruption')
    if len(x) > 0:
        print(annotation_file, x)
        if x[0][2] == 'light_off':
            i += 1
            if i == 1:
                min_start_time = x[0][0]
                max_end_time = x[0][1]
            elif i == 2:
                min_start_time = min(min_start_time, x[0][0])
                max_end_time = max(max_end_time, x[0][1])
            elif i == 3:
                min_start_time = min(min_start_time, x[0][0])
                max_end_time = max(max_end_time, x[0][1])

                print(f'Minimum start time: {min_start_time}')
                print(f'Maximum end time: {max_end_time}')
                i = 0
# Out:
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_1.eaf [(1562454, 1584669, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_2.eaf [(1562454, 1584669, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/09_3.eaf [(1562454, 1584669, 'light_off')]
# Minimum start time: 1562454
# Maximum end time: 1584669
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/11_3.eaf [(1467894, 1554839, 'participant_left')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_1.eaf [(942016, 974579, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_2.eaf [(942016, 974579, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/15_3.eaf [(942016, 974579, 'light_off')]
# Minimum start time: 942016
# Maximum end time: 974579
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_1.eaf [(1262789, 1292636, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_2.eaf [(1262789, 1292636, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/18_3.eaf [(1262789, 1292636, 'light_off')]
# Minimum start time: 1262789
# Maximum end time: 1292636
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_1.eaf [(1033008, 1056959, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_2.eaf [(1033008, 1056959, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/26_3.eaf [(1033008, 1056959, 'light_off')]
# Minimum start time: 1033008
# Maximum end time: 1056959
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_1.eaf [(914518, 933616, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_2.eaf [(914518, 933616, 'light_off')]
# /home/janko/Desktop/social-dining/data/annotation/annotation-files/28_3.eaf [(914518, 933616, 'light_off')]
# Minimum start time: 914518
# Maximum end time: 933616
